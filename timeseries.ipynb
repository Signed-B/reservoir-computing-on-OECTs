# %%
import shelve

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Time Series Plotting
#
# Intended to visualize the reservoir's capturing of the system's climate. Also visualizes the forecast horizon.

# %%
dimindex = 1  # index in reservoir_dims of the dimension to plot

with shelve.open("./Data/may8/dims_ensemble/data") as data:
    datadicts = data["dicts"]
    reservoir_dims = data["dims"]
    t = data["time"]

OECT_signals = datadicts[0]["OECT_signals"][dimindex]
OECT_predictions = datadicts[0]["OECT_predictions"][dimindex]
tanh_signals = datadicts[0]["tanh_signals"][dimindex]
tanh_predictions = datadicts[0]["tanh_predictions"][dimindex]

# %% [markdown]
# ##### Tanh plot

# %%
plt.figure(figsize=(10, 10))

plot_index = 1

start = 0
end = 1000
end_3d = 10000

to_signals = tanh_signals
to_predictions = tanh_predictions

x_sig = [sig[0] for sig in to_signals]
y_sig = [sig[1] for sig in to_signals]
z_sig = [sig[2] for sig in to_signals]
x_pred = [pred[0] for pred in to_predictions]
y_pred = [pred[1] for pred in to_predictions]
z_pred = [pred[2] for pred in to_predictions]

print("Length of timeseries:", len(x_sig))


# x
plt.subplot(3, 1, plot_index)
plt.title("x")
plt.plot(t[start:end], x_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], x_pred[start:end], "r-.", label="prediction")

if plot_index == 1:
    plt.legend()
plot_index += 1

# y
plt.subplot(3, 1, plot_index)
plt.title("y")
plt.plot(t[start:end], y_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], y_pred[start:end], "r-.", label="prediction")
plot_index += 1

# z
plt.subplot(3, 1, plot_index)
plt.title("z")
plt.plot(t[start:end], z_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], z_pred[start:end], "r-.", label="prediction")
plot_index += 1


plt.ylabel("Value")
plt.xlabel("time")
plt.show()
# Out:
# Length of timeseries: 10000

# %% [markdown]
# #### OECT Plot

# %%
plt.cla()
plt.clf()

plt.figure(figsize=(10, 10))
plot_index = 1

start = 0
end = 1000
end_3d = 10000

to_signals = OECT_signals
to_predictions = OECT_predictions

x_sig = [sig[0] for sig in to_signals]
y_sig = [sig[1] for sig in to_signals]
z_sig = [sig[2] for sig in to_signals]
x_pred = [pred[0] for pred in to_predictions]
y_pred = [pred[1] for pred in to_predictions]
z_pred = [pred[2] for pred in to_predictions]

print("Length of timeseries:", len(x_sig))


# x
plt.subplot(3, 1, plot_index)
plt.title("x")
plt.plot(t[start:end], x_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], x_pred[start:end], "r-.", label="prediction")

if plot_index == 1:
    plt.legend()
plot_index += 1

# y
plt.subplot(3, 1, plot_index)
plt.title("y")
plt.plot(t[start:end], y_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], y_pred[start:end], "r-.", label="prediction")
plot_index += 1

# z
plt.subplot(3, 1, plot_index)
plt.title("z")
plt.plot(t[start:end], z_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], z_pred[start:end], "r-.", label="prediction")
plot_index += 1


plt.ylabel("Value")
plt.xlabel("time")
plt.show()
# Out:
# Length of timeseries: 10000

# %% [markdown]
# #### Combined Plot

# %%
plt.cla()
plt.clf()

plt.figure(figsize=(6, 6))
# plt.suptitle("OECT vs tanh timeseries")
plt.subplots_adjust(top=0.93, hspace=0.5, wspace=0.5)
plot_index = 1

start = 0
end = 1000
end_3d = 10000

to_signals = OECT_signals
to_OECT = OECT_predictions
to_tanh = tanh_predictions

x_sig = [sig[0] for sig in to_signals]
y_sig = [sig[1] for sig in to_signals]
z_sig = [sig[2] for sig in to_signals]
x_oect = [pred[0] for pred in to_OECT]
y_oect = [pred[1] for pred in to_OECT]
z_oect = [pred[2] for pred in to_OECT]
x_tanh = [pred[0] for pred in to_tanh]
y_tanh = [pred[1] for pred in to_tanh]
z_tanh = [pred[2] for pred in to_tanh]


print("Length of timeseries:", len(x_sig))

# reduce space between plots
plt.subplots_adjust(hspace=0.3)

# x
plt.subplot(3, 1, plot_index)
plt.ylabel("x")
plt.plot(t[start:end], x_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], x_oect[start:end], "r--", label="OECT prediction")
plt.plot(t[start:end], x_tanh[start:end], "b-.", label="tanh prediction")

if plot_index == 1:
    plt.legend()
plot_index += 1

# y
plt.subplot(3, 1, plot_index)
plt.ylabel("y")
plt.plot(t[start:end], y_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], y_oect[start:end], "r--", label="OECT prediction")
plt.plot(t[start:end], y_tanh[start:end], "b-.", label="tanh prediction")
plot_index += 1

# z
plt.subplot(3, 1, plot_index)
plt.ylabel("z")
plt.plot(t[start:end], z_sig[start:end], "k-", label="ground truth")
plt.plot(t[start:end], z_oect[start:end], "r--", label="OECT prediction")
plt.plot(t[start:end], z_tanh[start:end], "b-.", label="tanh prediction")
plot_index += 1


# plt.ylabel("Value")
# plt.xlabel("time")
plt.show()
# Out:
# Length of timeseries: 10000

# %% [markdown]
# #### 3D Plot

# %%
end = end_3d


fig, ax = plt.subplots(1, 1, figsize=(7, 7), subplot_kw=dict(projection="3d"))
# ax[0].axes(projection='3d')

ax.plot3D(x_sig[start:end], y_sig[start:end], z_sig[start:end], "gray", lw=0.4)
ax.plot3D(x_pred[start:end], y_pred[start:end], z_pred[start:end], "r-.", lw=0.4)

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
# ax.set_title("OECT Attractor: n=100")

ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

# make the grid lines transparent
ax.xaxis._axinfo["grid"]["color"] = (1, 1, 1, 0)
ax.yaxis._axinfo["grid"]["color"] = (1, 1, 1, 0)
ax.zaxis._axinfo["grid"]["color"] = (1, 1, 1, 0)

# ax[0,1].axes(projection='3d')

# ax[0, 1].plot3D(x_sig[start:end], y_sig[start:end], z_sig[start:end], "gray")
# ax[0, 1].plot3D(x_pred[start:end], y_pred[start:end], z_pred[start:end], "r-.", lw=0.5)

# ax[0, 1].set_xlabel("X")
# ax[0, 1].set_ylabel("Y")
# ax[0, 1].set_zlabel("Z")
# ax[0, 1].set_title("Attractor Results")
# ax[0, 1].view_init(15, 60)

# ax[1, 0].plot3D(x_sig[start:end], y_sig[start:end], z_sig[start:end], "gray")
# ax[1, 0].plot3D(x_pred[start:end], y_pred[start:end], z_pred[start:end], "r-.", lw=0.5)

# ax[1, 0].set_xlabel("X")
# ax[1, 0].set_ylabel("Y")
# ax[1, 0].set_zlabel("Z")
# ax[1, 0].set_title("Attractor Results")
# ax[1, 0].view_init(65, 85)

# ax[1, 1].plot3D(x_sig[start:end], y_sig[start:end], z_sig[start:end], "gray")
# ax[1, 1].plot3D(x_pred[start:end], y_pred[start:end], z_pred[start:end], "r-.", lw=0.5)

# ax[1, 1].set_xlabel("X")
# ax[1, 1].set_ylabel("Y")
# ax[1, 1].set_zlabel("Z")
# ax[1, 1].set_title("Attractor Results")
# ax[1, 1].view_init(-30, 50)

# reduce whitespace around 3d plot
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

plt.show()
